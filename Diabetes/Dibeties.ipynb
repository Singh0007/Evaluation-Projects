# %%
import pandas as pd

# %%
df=pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# after we have to perform eda (Exploratory data analysis)

# %% [markdown]
# in this step we have to perform two types of analyssi first one is non graphically and other one graphically

# %% [markdown]
# non graphicalyy mean we can analysios with the help of describe method which can provide the details of the whole column with corrrespnding mena,median ,perntiales and count of the oclumns and standard deviation

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %% [markdown]
# no we can clearly see ther is count column through this column we can check if the count of every colunm in same then ther is no missing cvalues present in that dataset
#
# 2) this can show the mean of every column we can check form there the skewness of the data types so we can check mean in correspods wtih mendian or 50% percenmtile
#
# 1 if the mean is graetor than the median than the disribution is of rigth taild or +ly skewed it can also show the directio of the outliers
#
# 2) if the mean is lower than the median thus can show the negativelu skewed cvalues and the left tails of if there i no diffrence or little diffrenc menans that the vaklues are normallyu distruvbuted
#
# 3) we can check the mininum and the maxinum values of each column so after that we can move further to the graphicvally step which is done with the helkp of ploting

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Pregnancies' ,y='Outcome',data=df)
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Outcome'>

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
sns.scatterplot(x='Glucose',y='Outcome',data=df)
# Out:
# <Axes: xlabel='Glucose', ylabel='Outcome'>

# %%
sns.scatterplot(x='BloodPressure',y='Outcome',data=df)
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Outcome'>

# %%
sns.scatterplot(x='SkinThickness',y='Outcome',data=df)
# Out:
# <Axes: xlabel='SkinThickness', ylabel='Outcome'>

# %%
sns.scatterplot(x='BMI',y='Outcome',data=df)
# Out:
# <Axes: xlabel='BMI', ylabel='Outcome'>

# %%
sns.scatterplot(x='Insulin',y='Outcome',data=df)
# Out:
# <Axes: xlabel='Insulin', ylabel='Outcome'>

# %%
sns.scatterplot(x='DiabetesPedigreeFunction',y='Outcome',data=df)
# Out:
# <Axes: xlabel='DiabetesPedigreeFunction', ylabel='Outcome'>

# %%
sns.scatterplot(x='Age',y='Outcome',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Outcome'>

# %%
df.Outcome.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
x=df.drop(['Outcome'],axis=1)
y=df['Outcome']

# %%
x.shape
# Out:
# (768, 8)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(18,13))
p=1
for i in x:
    if p<9:
        plt.subplot(3,3,p)
        sns.boxplot(df[i])
        plt.xlabel(i)
        
    p +=1

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
from scipy.stats import zscore

# %%
import numpy as np

# %%
z=np.abs(zscore(x))

# %%
z.shape
# Out:
# (768, 8)

# %%
threshold=3

# %%
print(np.where(z>3))
# Out:
# (array([  4,   7,   8,   9,  13,  15,  45,  49,  49,  58,  60,  60,  75,
#         78,  81,  81,  88, 111, 123, 145, 153, 159, 172, 177, 182, 186,
#        193, 220, 222, 228, 228, 247, 261, 266, 269, 286, 298, 300, 330,
#        332, 336, 342, 347, 349, 357, 370, 370, 371, 371, 395, 409, 415,
#        426, 426, 430, 435, 445, 445, 453, 453, 455, 459, 468, 484, 486,
#        494, 494, 502, 522, 522, 533, 535, 579, 584, 589, 593, 601, 604,
#        619, 621, 643, 645, 655, 666, 673, 684, 684, 695, 697, 703, 706,
#        706, 753], dtype=int64), array([6, 2, 4, 5, 4, 2, 6, 2, 5, 6, 2, 5, 1, 2, 2, 5, 0, 4, 7, 5, 4, 0,
#        2, 5, 1, 4, 2, 4, 2, 4, 6, 4, 2, 2, 2, 4, 0, 2, 6, 2, 2, 1, 2, 1,
#        2, 4, 6, 5, 6, 6, 4, 4, 2, 5, 2, 2, 5, 6, 2, 7, 0, 7, 2, 2, 4, 2,
#        5, 1, 2, 5, 2, 2, 3, 4, 2, 6, 2, 2, 2, 6, 2, 4, 4, 7, 5, 5, 7, 4,
#        2, 2, 2, 5, 4], dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]

# %%
print(df1.shape)
print(df.shape)
# Out:
# (688, 9)
# (768, 9)

# %%
x=x[(z<3).all(axis=1)]

# %%
x.shape
# Out:
# (688, 8)

# %%
y=y[(z<3).all(axis=1)]

# %%
y.shape
# Out:
# (688,)

# %%
print("percentage of data loss" ,(df.shape[0]-df1.shape[0])/df.shape[0]*100)
# Out:
# percentage of data loss 10.416666666666668

# %%
x.shape
# Out:
# (688, 8)

# %% [markdown]
# now its time to remove the skewness with the help of transformation

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pr=PowerTransformer(method='yeo-johnson')

# %%
x1=pd.DataFrame(pr.fit_transform(x),columns=x.columns)

# %%
x1
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.814991  0.959243      -0.019336       0.881292 -1.040847  0.281442
# 1      -0.865680 -1.273024      -0.508776       0.613395 -1.040847 -0.832919
# 2       1.203973  1.834209      -0.672909      -1.479707 -1.040847 -1.433294
# 3      -0.865680 -1.090911      -0.508776       0.321256  0.841467 -0.577677
# 4       0.585579 -0.031028       0.142875      -1.479707 -1.040847 -1.008903
# ..           ...       ...            ...            ...       ...       ...
# 683     1.528423 -0.587184       0.304641       1.402776  1.114564  0.178048
# 684    -0.365573  0.172735      -0.182005       0.519067 -1.040847  0.735106
# 685     0.585579  0.139436      -0.019336       0.321256  0.914811 -0.902731
# 686    -0.865680  0.303420      -1.002757      -1.479707 -1.040847 -0.252235
# 687    -0.865680 -0.916293      -0.182005       0.705057 -1.040847 -0.204780
#
#      DiabetesPedigreeFunction       Age
# ...

# %% [markdown]
# now its time to scale the features

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_new=pd.DataFrame(sc.fit_transform(x1),columns=x1.columns)

# %%
x_new
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.814991  0.959243      -0.019336       0.881292 -1.040847  0.281442
# 1      -0.865680 -1.273024      -0.508776       0.613395 -1.040847 -0.832919
# 2       1.203973  1.834209      -0.672909      -1.479707 -1.040847 -1.433294
# 3      -0.865680 -1.090911      -0.508776       0.321256  0.841467 -0.577677
# 4       0.585579 -0.031028       0.142875      -1.479707 -1.040847 -1.008903
# ..           ...       ...            ...            ...       ...       ...
# 683     1.528423 -0.587184       0.304641       1.402776  1.114564  0.178048
# 684    -0.365573  0.172735      -0.182005       0.519067 -1.040847  0.735106
# 685     0.585579  0.139436      -0.019336       0.321256  0.914811 -0.902731
# 686    -0.865680  0.303420      -1.002757      -1.479707 -1.040847 -0.252235
# 687    -0.865680 -0.916293      -0.182005       0.705057 -1.040847 -0.204780
#
#      DiabetesPedigreeFunction       Age
# ...

# %% [markdown]
# #  now its itme to check for the data is balce or not

# %%
y.value_counts()
# Out:
# Outcome
# 0    461
# 1    227
# Name: count, dtype: int64

# %% [markdown]
# so it clearly seen that the target varivale valeus are not balance so its bettwe to balance them

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()

# %%
x_new,y=sm.fit_resample(x_new,y)

# %%
x_new
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.814991  0.959243      -0.019336       0.881292 -1.040847  0.281442
# 1      -0.865680 -1.273024      -0.508776       0.613395 -1.040847 -0.832919
# 2       1.203973  1.834209      -0.672909      -1.479707 -1.040847 -1.433294
# 3      -0.865680 -1.090911      -0.508776       0.321256  0.841467 -0.577677
# 4       0.585579 -0.031028       0.142875      -1.479707 -1.040847 -1.008903
# ..           ...       ...            ...            ...       ...       ...
# 917     0.439189  0.095993      -0.105239       0.052747  0.975144 -0.407393
# 918     0.322917  0.192729      -0.155419       0.267206  0.987143 -0.245887
# 919     1.372754  0.308594      -0.726683      -1.479707 -1.040847  0.306696
# 920     0.869356  0.956462       0.577103       0.564101  1.083584  0.349774
# 921    -1.634893  1.165995      -0.565890       0.555544  1.073078  1.439694
#
#      DiabetesPedigreeFunction       Age
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(x_new.values,i) for i in range(x_new.shape[1])]
vif['features']=x_new.columns

# %%
vif
# Out:
#         VIF                  features
# 0  1.598343               Pregnancies
# 1  1.234371                   Glucose
# 2  1.291378             BloodPressure
# 3  1.892823             SkinThickness
# 4  1.836975                   Insulin
# 5  1.273021                       BMI
# 6  1.114609  DiabetesPedigreeFunction
# 7  1.892818                       Age

# %%
y.value_counts()
# Out:
# Outcome
# 1    461
# 0    461
# Name: count, dtype: int64

# %% [markdown]
# now its time to build this classification model

# %%
from sklearn.metrics import classification_report ,confusion_matrix,roc_curve,accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
maxaccu=0
maxrs=0
for i in range(1,500):
    x_train,x_test,y_train,y_test=train_test_split(x_new,y,random_state=i,test_size=.20)
    lr=LogisticRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    accu=accuracy_score(y_test,y_pred)
    if accu>maxaccu:
        maxaccu=accu
        maxrs=i
print("best accuracy is ",maxaccu,"at the random state is ",maxrs)
# Out:
# best accuracy is  0.8540540540540541 at the random state is  141

# %%
from sklearn.metrics import classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x_new,y,random_state=141,test_size=.20)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
print("#"*100)
print(classification_report(y_test,y_pred))
# Out:
# 0.8540540540540541
# ####################################################################################################
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        96
#            1       0.85      0.84      0.85        89
#
#     accuracy                           0.85       185
#    macro avg       0.85      0.85      0.85       185
# weighted avg       0.85      0.85      0.85       185

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC

# %%
x_train,x_test,y_train,y_test=train_test_split(x_new,y,random_state=141,test_size=0.20)

# %%
m=[DecisionTreeClassifier(),RandomForestClassifier(),ExtraTreesClassifier(),GradientBoostingClassifier(),AdaBoostClassifier(),SVC()]
for i in m:    
    i.fit(x_train,y_train)
    y_pred=i.predict(x_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',i,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(y_test, y_pred))
    print('\n')
    print('============================================================================================================')
# Out:
# Classification ML Algorithm Evaluation Matrix DecisionTreeClassifier() is
#
#
# Accuracy Score :
#  0.772972972972973
#
#
# Confusion matrix :
#  [[68 28]
#  [14 75]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.83      0.71      0.76        96
#            1       0.73      0.84      0.78        89
#
#     accuracy                           0.77       185
#    macro avg       0.78      0.78      0.77       185
# weighted avg       0.78      0.77      0.77       185
#
#
#
# ...
# Classification ML Algorithm Evaluation Matrix RandomForestClassifier() is
#
#
# Accuracy Score :
#  0.8864864864864865
#
#
# Confusion matrix :
#  [[85 11]
#  [10 79]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89        96
#            1       0.88      0.89      0.88        89
#
#     accuracy                           0.89       185
# ...

# %%
from sklearn.model_selection import cross_val_score
for i in m:
    i.fit(x_train,y_train)
    y_pred=i.predict(x_test)
    score = cross_val_score(i, x_new, y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', i, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("diffrence between accuracy_Score and score mean:",accuracy_score(y_test,y_pred)-score.mean())
    print('\n')
    print('============================================================================================================')
# Out:
# Cross Validation Score DecisionTreeClassifier() :
#
# Score : [0.75675676 0.75675676 0.82608696 0.80434783 0.79347826]
# Mean Score : 0.787485311398355
# diffrence between accuracy_Score and score mean: -0.025323149236192832
#
#
# ...
#
#
# Cross Validation Score RandomForestClassifier() :
#
# Score : [0.77837838 0.78918919 0.86413043 0.91847826 0.85869565]
# Mean Score : 0.8417743830787309
# diffrence between accuracy_Score and score mean: 0.028495887191539393
#
#
# ...
#
#
# Cross Validation Score ExtraTreesClassifier() :
#
# Score : [0.8        0.78918919 0.875      0.91847826 0.89130435]
# Mean Score : 0.8547943595769683
# diffrence between accuracy_Score and score mean: 0.03709753231492363
#
#
# ...
#
#
# Cross Validation Score GradientBoostingClassifier() :
#
# Score : [0.75135135 0.76216216 0.85869565 0.86956522 0.83695652]
# Mean Score : 0.8157461809635723
# diffrence between accuracy_Score and score mean: 0.059929494712103404
#
#
# ...
#
#
# Cross Validation Score AdaBoostClassifier() :
#
# ...

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt'],
    'criterion': ['gini', 'entropy']
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
gcv=GridSearchCV(RandomForestClassifier(),cv=5,param_grid=param_grid,verbose=2)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
gcv.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [CV] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.2s
# ...

# %%
gcv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
final_model=RandomForestClassifier(criterion= 'entropy', max_depth= None,
                                  max_features= 'sqrt', min_samples_leaf= 1, min_samples_split= 2, n_estimators= 100)

# %%
final_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
pred=final_model.predict(x_test)

# %%
accu=accuracy_score(y_test,pred)

# %%
print(accu*100)
# Out:
# 87.56756756756758

# %%
from scikitplot.metrics import plot_roc_curve
from sklearn.metrics import RocCurveDisplay

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
#from sklearn.metrics import plot_roc_curve
disp =RocCurveDisplay.from_estimator(final_model,x_test,y_test)   
plt.legend(prop={'size':10}, loc='lower right')
plt.figure(figsize=(10,10))
plt.show()
plt.show()
auc_score = roc_auc_score(y_test, final_model.predict(x_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  0.8757022471910112

# %%
# Lets plot confusion matrix for  FinalModel
Matrix = confusion_matrix(y_test, y_pred)

x_labels = ["NO","YES"]
y_labels = ["NO","YES"]

fig , ax = plt.subplots(figsize=(5,5))
sns.heatmap(Matrix, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, 
            cmap="plasma", xticklabels = x_labels, yticklabels = y_labels)

plt.xlabel("Predicted Label",fontsize=14,fontweight='bold')
plt.ylabel("True Label",fontsize=14,fontweight='bold')
plt.title('Confusion Matrix for Final Model',fontsize=20,fontweight='bold')
plt.show()

# %%
import joblib
joblib.dump(final_model,'diabetes.pkl')
# Out:
# ['diabetes.pkl']
